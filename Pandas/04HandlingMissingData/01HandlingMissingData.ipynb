# %% [markdown]
# Handling Missing Data - fillna, interpolate, dropna
# ---------------------------------------------------

# %%
import pandas as pd

# %%
# parse_dates - Create as a separate date column.

df = pd.read_csv("01weather_data.csv",parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# fillna
# ------
#
#     Fill all NaN with one specific value

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# Change based on column values

new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'No Event'
    })
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  No Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %% [markdown]
# Use method to determine how to fill na values
# ---------------------------------------------

# %%
# ffill: propagate last valid observation forward to next valid.

new_df = df.fillna(method="ffill")
new_df
# Out:
# C:\Users\Selva\AppData\Local\Temp\ipykernel_5264\3085495511.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill")
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# backfill / bfill: use next valid observation to fill gap.

new_df = df.fillna(method="bfill")
new_df
# Out:
# C:\Users\Selva\AppData\Local\Temp\ipykernel_5264\203606522.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="bfill")
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Use of axis
# -----------

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
# C:\Users\Selva\AppData\Local\Temp\ipykernel_5264\3318019960.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
# C:\Users\Selva\AppData\Local\Temp\ipykernel_5264\3318019960.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         9.0       9.0   Sunny
# 2017-01-05        28.0      Snow    Snow
# 2017-01-06         7.0       7.0     NaN
# 2017-01-07        32.0      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %% [markdown]
# limit parameter
# ---------------

# %%
new_df = df.fillna(method="ffill",limit=1)
new_df
# Out:
# C:\Users\Selva\AppData\Local\Temp\ipykernel_5264\2057544078.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill",limit=1)
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# interpolate
# -----------
#
# The interpolate() method in pandas calculates missing numeric values by using interpolation techniques. By default, it uses linear interpolation, filling in missing values by assuming a straight-line relationship between adjacent known values.
#
# Step 1: Interpolating temperature
# ---------------------------------
#
#     1. Calculation for each missing value - numeric values only
#
#                    (x − x1)
#         y = y1 − ------------  * (y2 - y1)
#                    (x2 - x1)
#
#     1. x1, y1, x2, y2 are the known points on either side of the missing value.
#
#     2. x is the position of the missing value.
#
#
# Interpolation for temperature
# -----------------------------
# Original values in temperature:
# -------------------------------
#         [32.0,NaN,28.0,NaN,32.0,NaN,NaN,34.0,40.0]
#
#     1. 2017-01-04 (NaN):
#
#         x1 = 2017-01-01
#
#         x2 = 2017-01-05
#
#         y1 = 32.0
#
#         y2 = 28.0
#
#                         (4−1)
#             y = 32.0 + ------- ×(28.0 − 32.0) ==> y = 32.0 + (−4.0 × 0.75) ===> y = 29.0
#                         (5−1)
#
#     2. 2017-01-06 (NaN):
#
#         x1 = 2017-01-05
#
#         x2 = 2017-01-07
#
#         y1 = 28.0
#
#         y2 = 32.0
#
#                         (6−5)
#             y = 28.0 + ------- ×(32.0 − 28.0) ==> y = 28.0 + (4.0 × 0.5) ===> y = 30.0
#                         (7−5)
#
# Interpolation for windspeed:
# ----------------------------
# Original values in windspeed:
# -----------------------------
#
#         [6.0,9.0,NaN,7.0,NaN,NaN,NaN,8.0,12.0]
#
#     1. 2017-01-05 (NaN):
#
#         x1 = 2017-01-04
#
#         x2 = 2017-01-06
#
#         y1 = 9.0
#
#         y2 = 7.0
#
#                         (5−4)
#             y = 9.0 + ------- ×(7.0 − 9.0) ==> y = 9.0 − (2.0 × 0.5) ===> y 9.0 - 1.0 ===> y = 8.0
#                         (6−4)
#
#
#     2. 2017-01-07 (NaN):
#
#         x1 = 2017-01-06
#
#         x2 = 2017-01-10
#
#         y1 = 7.0
#
#         y2 = 8.0
#
#                         (7−6)
#             y = 7.0 + ------- × (8.0 − 7.0) ==> y = 7.0 + (1.0 × 0.25) ===> y = 7.25
#                         (10−6)
#
#
#     3. 2017-01-08 (NaN):
#
#         x1 = 2017-01-06
#
#         x2 = 2017-01-10
#
#         y1 = 7.0
#
#         y2 = 8.0
#
#                         (8−6)
#             y = 7.0 + ------- × (8.0 − 7.0) ==> y = 7.0 + (2.0 × 0.25) ===> y = 7.5
#                         (10−6)
#
#     4. 2017-01-09 (NaN):
#
#         x1 = 2017-01-06
#
#         x2 = 2017-01-10
#
#         y1 = 7.0
#
#         y2 = 8.0
#
#                         (9−6)
#             y = 7.0 + ------- × (8.0 − 7.0) ==> y = 7.0 + (3.0 × 0.25) ===> y = 7.75
#                         (10−6)
#
#
# There are many other methods for interpolation such as quadratic, piecewise_polynomial, cubic etc. Just google "dataframe interpolate" to see complete documentation

# %%
# day column is index mandatary

new_df = df.interpolate(method="time") 
new_df
# Out:
# C:\Users\Selva\AppData\Local\Temp\ipykernel_1196\1891485727.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method="time")
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# dropna
# ------

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
'''
how : {'any', 'all'}, default 'any'
    Determine if row or column is removed from DataFrame, when we have
    at least one NA or all NA.

    * 'any' : If any NA values are present, drop that row or column.
    * 'all' : If all values are NA, drop that row or column.
2017-01-09 row have all NaN value so delete the row
'''

new_df = df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
'''
thresh : int, optional
    Require that many non-NA values. Cannot be combined with how.
'''

new_df = df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Inserting Missing Dates
# -----------------------

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
df.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny
